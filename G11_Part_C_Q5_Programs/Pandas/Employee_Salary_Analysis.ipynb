# %%
'''
Create a DataFrame containing employee names, departments, and salaries.
Display employees earning more than ₹50,000.
'''

import pandas as pd

names = []
departments = []
salaries = []

for i in range(5):
    name = input("Enter employee name: ")
    department = input("Enter department: ")
    salary = float(input("Enter salary: "))

    names.append(name)
    departments.append(department)
    salaries.append(salary)

df = pd.DataFrame({
    "Name": names,
    "Department": departments,
    "Salary": salaries
})

print("\nEmployee Data:")
print(df)

print("\nEmployees earning above ₹50,000:")
print(df[df["Salary"] > 50000])
# Out:
# Enter employee name: divya
# Enter department: cs
# Enter salary: 80000
# Enter employee name: aji
# Enter department: logistics
# Enter salary: 90000
# Enter employee name: santha
# Enter department: dev
# Enter salary: 900000
# Enter employee name: devika
# Enter department: civil
# Enter salary: 87000
# Enter employee name: sree
# Enter department: abc
# Enter salary: 56000
#
# Employee Data:
#      Name Department    Salary
# 0   divya         cs   80000.0
# 1     aji  logistics   90000.0
# 2  santha        dev  900000.0
# 3  devika      civil   87000.0
# 4    sree        abc   56000.0
#
# Employees earning above ₹50,000:
#      Name Department    Salary
# 0   divya         cs   80000.0
# 1     aji  logistics   90000.0
# 2  santha        dev  900000.0
# 3  devika      civil   87000.0
# 4    sree        abc   56000.0
