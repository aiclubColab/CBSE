# %%
l = int(input("Enter length: "))
b = int(input("Enter breadth: "))

area = l * b
perimeter = 2 * (l + b)

print("Area:", area)
print("Perimeter:", perimeter)
# Out:
# Enter length: 4
# Enter breadth: 2
# Area: 8
# Perimeter: 12
