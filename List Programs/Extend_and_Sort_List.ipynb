# %%
# Extend_and_Sort_List

List_1 = [10, 20, 30, 40]

# Extend list
List_1.extend([14, 15, 12])

# Sort list
List_1.sort()

print("Final sorted list:", List_1)
# Out:
# Final sorted list: [10, 12, 14, 15, 20, 30, 40]
