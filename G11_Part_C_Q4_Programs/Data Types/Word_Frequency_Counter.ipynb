# %%
#Accept a paragraph and create a dictionary containing each word and its frequency.

text = input("Enter a sentence: ").lower()

words = text.split()
unique_words = set(words)

frequency = {}

for word in unique_words:
    frequency[word] = words.count(word)

print("\nWord Frequency")

for word, count in frequency.items():
    print(word, ":", count)
# Out:
# Enter a sentence: I love my grandmother
#
# Word Frequency
# i : 1
# love : 1
# my : 1
# grandmother : 1
