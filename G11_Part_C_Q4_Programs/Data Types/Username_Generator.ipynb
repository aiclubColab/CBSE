# %%
#Create a username using the first three characters of the student's name and the last two digits of their year of birth.

name = input("Enter your full name: ")
year = input("Enter your birth year: ")

first_name = name.split()[0]

username = first_name[:3].lower() + year[-2:]

print("Generated Username:", username)
# Out:
# Enter your full name: divyasree
# Enter your birth year: 1997
# Generated Username: div97
