# %%
#Create_Array_and_Display_Elements
import numpy as np

arr = np.array([10, 20, 30, 40])
print("Array:", arr)
# Out:
# Array: [10 20 30 40]

# %%
#Find_Mean_Median_and_Standard_Deviation
import numpy as np

arr = np.array([10, 20, 30, 40, 50])
print("Mean:", np.mean(arr))
print("Median:", np.median(arr))
print("Standard Deviation:", np.std(arr))
# Out:
# Mean: 30.0
# Median: 30.0
# Standard Deviation: 14.142135623730951

# %%
#Find_Maximum_and_Minimum
import numpy as np

arr = np.array([5, 15, 25, 35])
print("Maximum:", np.max(arr))
print("Minimum:", np.min(arr))
# Out:
# Maximum: 35
# Minimum: 5

# %%
#Perform_Basic_Array_Operations
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
# Out:
# Addition: [5 7 9]
# Subtraction: [-3 -3 -3]
# Multiplication: [ 4 10 18]

# %%
#Reshape_Array
import numpy as np

arr = np.array([1, 2, 3, 4, 5, 6])
reshaped = arr.reshape(2, 3)

print("Reshaped Array:\n", reshaped)
# Out:
# Reshaped Array:
#  [[1 2 3]
#  [4 5 6]]
