# %%
# Define two lists
list1 = [10, 20, 30, 40]
list2 = [1, 2, 3, 4]


# Add corresponding elements
result = []


for i in range(len(list1)):
    result.append(list1[i] + list2[i])


# Display the result
print("Sum of the two lists:", result)
# Out:
# Sum of the two lists: [11, 22, 33, 44]
