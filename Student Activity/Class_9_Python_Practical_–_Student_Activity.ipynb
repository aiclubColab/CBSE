# %% [markdown]
# # 📘 Class 9 Python Practical – Student Activity (Fill in the Blanks)
#
# Complete the programs below by filling in the blanks and run them.

# %% [markdown]
# ## Program: Area_and_Perimeter_of_a_Rectangle

# %%
length = float(input("Enter length: "))
breadth = __________________________

area = __________________________
perimeter = __________________________

print("Area =", area)
print("Perimeter =", perimeter)

# %% [markdown]
# ## Program: Area_of_a_Triangle

# %%
base = float(input("Enter base: "))
height = __________________________

area = __________________________

print("Area =", area)

# %% [markdown]
# ## Program: Average_of_3_Subjects

# %%
m1 = float(input("Enter marks 1: "))
m2 = __________________________
m3 = __________________________

average = __________________________

print("Average =", average)

# %% [markdown]
# ## Program: Discounted_Amount_Calculation

# %%
amount = float(input("Enter amount: "))
discount = __________________________

discount_amount = __________________________
final_amount = __________________________

print("Final Amount =", final_amount)

# %% [markdown]
# ## Program: Surface_Area_and_Volume_of_a_Cuboid

# %%
length = float(input("Enter length: "))
breadth = __________________________
height = __________________________

surface_area = __________________________
volume = __________________________

print("Surface Area =", surface_area)
print("Volume =", volume)

# %% [markdown]
# ## Program: List_Operations_Science_Quiz

# %%
students = ["Arjun", "Sonakshi", "Vikram", "Sandhya", "Sonal", "Isha", "Kartik"]

print("Original list:", students)

students.__________________("Vikram")
students.__________________("Jay")
students.__________________(1)

print("Updated list:", students)

# %% [markdown]
# ## Program: List_Indexing_Operations

# %%
num = [23, 12, 5, 9, 65, 44]

print("Length:", __________________________)
print("2nd to 4th:", __________________________)
print("Negative indexing:", __________________________)

# %% [markdown]
# ## Program: Voting_Eligibility_Check

# %%
age = int(input("Enter age: "))

if age ________ 18:
    print("Eligible")
else:
    print("Not eligible")

# %% [markdown]
# ## Program: Grade_Check_Program

# %%
marks = int(input("Enter marks: "))

if marks >= ________:
    print("A")
elif marks >= ________:
    print("B")
elif marks >= ________:
    print("C")
else:
    print("Fail")

# %% [markdown]
# ## Program: First_10_Natural_Numbers

# %%
for i in range(________, ________):
    print(i)

# %% [markdown]
# ## Program: Sum_of_First_10_Natural_Numbers

# %%
total = 0

for i in range(________, ________):
    total += ________

print("Sum =", total)
