# %%
# Read_CSV_Display_10_Rows

import pandas as pd

df = pd.read_csv("/content/age_project_1_and_2 (3).csv")

print(df.head(10))
# Out:
#    num_countries  years_school  height who_am_I
# 0              2             0    2.18    child
# 1              8             7    5.58    adult
# 2              2             4    5.95    adult
# 3              3             4    4.36    child
# 4              5             2    5.53    adult
# 5              8             9    5.38    child
# 6              8            11    5.29    adult
# 7              1             4    5.91    adult
# 8              4             0    3.96    child
# 9              6             1    2.72    child
