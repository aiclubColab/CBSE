# %%
# Read_CSV_Display_Info

import pandas as pd

df = pd.read_csv("/content/age_project_1_and_2 (3).csv")

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   num_countries  1000 non-null   int64
#  1   years_school   1000 non-null   int64
#  2   height         1000 non-null   float64
#  3   who_am_I       1000 non-null   object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 31.4+ KB
# None
